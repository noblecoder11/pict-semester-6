# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import sklearn

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv('housing.csv', header = None, delimiter = r'\s+', names = column_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %%
features = ['LSTAT', 'RM', 'PTRATIO', 'TAX']

X = df[features]
y = df['MEDV']

print("Independent variables: ")
print(X.head())

print("\nDependent variable: ")
print(y.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-782ec95c5c5f> in <cell line: 3>()
#       1 features = ['LSTAT', 'RM', 'PTRATIO', 'TAX']
#       2
# ----> 3 X = df[features]
#       4 y = df['MEDV']
#       5
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2)


print("X_train", X_train.shape)
print("X_test", X_test.shape)
print("y_train", y_train.shape)
print("y_test", y_test.shape)
# Out:
# X_train (379, 4)
# X_test (127, 4)
# y_train (379,)
# y_test (127,)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

print(y_pred)
# Out:
# [22.57976438 20.64695537 31.14919997 28.79606654  1.69097871  2.0628481
#  27.82158588 28.23380195 19.39112763 24.35428528 29.73990141 27.45637619
#  23.05674544 17.09551746 15.8171306  26.08717812 18.16593751 11.57282413
#  11.58158718 17.94653542 24.84078625 19.24574913 34.37195202 19.5072471
#  19.44946929 17.38254039 37.3300719  35.70281244 32.1013533  25.78692295
#  16.65062678 22.93683222 31.99829855 29.34656016 12.1289415  20.75569512
#  10.76779501 20.37369179 24.73554059 23.00938847 27.92990495 12.58003266
#  30.83326222  4.26185495 21.14453635 18.41532772 34.89028107 17.72205072
#  33.46897335  0.69871411 30.20373926 29.73675262  6.43669417 33.73719505
#  17.59532113 21.2749033  20.87049592 17.34730471 16.80160296 18.68936863
#  21.03978476 21.9755898  18.74293395 28.37425691 32.91046725 24.09707784
#  38.19260991 27.82651429 11.69405423 28.85147552 10.4347458   3.6696916
#  21.84246291 16.55874026 26.96846291 26.25298828 24.47646744 22.94069311
#  23.99365671 25.03048071 32.30131739 18.44790083 19.59243121 29.98126863
#  36.74223667 35.10083929 19.74196294 27.06700695 32.20031719 17.11677133
#  22.6953475  20.98059061 16.59113927 35.71861994 38.32669657 11.88621133
#  34.75261532 32.17045796 22.21035458 13.87956825 31.5142636  25.47018742
#  25.43995328 22.45287184 22.74475931 32.31496706 15.26761548 16.29137936
#  19.68334364 13.53196509 18.82365653 20.22367685 13.39419431 10.93067004
#  31.222924   21.7185489  31.41150708 18.05296815 25.5493324  23.19962504
#  33.69824775 20.3317708  29.79563161  6.58685127 37.58149494 25.08260756
#  21.48858663]

# %%
import math
from sklearn.metrics import mean_squared_error, r2_score

rmse = math.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("RMSE: ", rmse)
print("R2 Score: ", r2)
# Out:
# RMSE:  4.984049414011468
# R2 Score:  0.7201087172461637

# %%
sns.scatterplot(x = y_test, y = y_pred)

plt.plot([y_pred.min(), y_pred.max()], [y_test.min(), y_test.max()])
