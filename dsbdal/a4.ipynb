# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.lmplot(data=df, x="Age", y="Fare", col="Sex", hue="Pclass")

# %%
sns.lmplot(data=df, x="Age", y="Fare", col="Survived", hue="Pclass")

# %%
sns.displot(data=df, x="Fare", kde=True).set(title="Fare vs Count Distribution")

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.catplot(data=df, x="Survived", y="Age")

# %%
# survived vs gender, embarked, class

print(df['Embarked'].value_counts())

print(df['Survived'].value_counts())

print(df['Sex'].value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# 0    549
# 1    342
# Name: Survived, dtype: int64
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.boxplot(data = df, x = 'Age').set_title("Age boxplot")
# Out:
# Text(0.5, 1.0, 'Age boxplot')

# %%
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
for col in cols:
    varcnt = df[col].value_counts()
    plt.bar(varcnt.index, varcnt)
    plt.title(f"{col}")
    plt.show()

# %%
# embarked vs alive
# g = sns.catplot(
#     data=df, kind="bar",
#     x="Embarked", y = df['Survived'].value_counts(), hue="Survived",
    
# )
# varcnt = df['Survived'].value_counts()[0]
# plt.bar(, varcnt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-f9e6e5ab7c0d> in <module>
#       1 # embarked
# ----> 2 g = sns.catplot(
#       3     data=df, kind="bar",
#       4     x="Embarked", y = df['Survived'].value_counts(), hue="Survived",
#       5
#
# /usr/local/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3845
# ...
